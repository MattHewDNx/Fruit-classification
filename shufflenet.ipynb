# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

def train_model():
    # Path to data
    data_dir = r'C:\Users\Matthew\Documents\collage\Software engineering\data'

    # Define transforms for training, validation, and test sets
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'validation': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'test': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

    # Load datasets
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
                      for x in ['train', 'validation', 'test']}
    dataloaders = {x: DataLoader(image_datasets[x], batch_size=32, shuffle=True, num_workers=4)
                   for x in ['train', 'validation', 'test']}

    # Define the device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Load the ShuffleNet model
    weights = models.ShuffleNet_V2_X1_0_Weights.DEFAULT
    model = models.shufflenet_v2_x1_0(weights=weights)
    num_ftrs = model.fc.in_features
    num_classes = len(image_datasets['train'].classes)
    model.fc = nn.Linear(num_ftrs, num_classes)
    model = model.to(device)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    # Training loop
    num_epochs = 20
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    best_acc = 0.0
    best_model_wts = model.state_dict()  # Initialize best_model_wts

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase == 'train':
                train_losses.append(epoch_loss)
                train_accuracies.append(epoch_acc)
            else:
                val_losses.append(epoch_loss)
                val_accuracies.append(epoch_acc)

            if phase == 'validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = model.state_dict()

    print('Training complete')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    # Test the model
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in dataloaders['test']:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(12, 12))
    cmd = ConfusionMatrixDisplay(cm, display_labels=image_datasets['train'].classes)
    cmd.plot(cmap=plt.cm.Blues)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
    plt.title('Confusion Matrix')
    plt.show()

    # Plot training and validation loss
    plt.figure(figsize=(12, 12))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    # Plot training and validation accuracy
    epochs = range(1, num_epochs + 1)
    plt.figure(figsize=(12, 12))
    plt.plot(epochs, train_accuracies, label='Train Accuracy', marker='o')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='x')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.show()

    # Save results
    results = {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'confusion_matrix': cm,
        'class_names': image_datasets['train'].classes
    }
    torch.save(results, 'shufflenet_training_results.pth')

if __name__ == '__main__':
    train_model()
# Out:
# Epoch 1/20
# ----------
# train Loss: 3.0896 Acc: 0.0854
# validation Loss: 3.0843 Acc: 0.1152
# Epoch 2/20
# ----------
# train Loss: 3.0848 Acc: 0.1099
# validation Loss: 3.0791 Acc: 0.1242
# Epoch 3/20
# ----------
# train Loss: 3.0798 Acc: 0.1241
# validation Loss: 3.0727 Acc: 0.1273
# Epoch 4/20
# ----------
# train Loss: 3.0750 Acc: 0.1357
# validation Loss: 3.0666 Acc: 0.1364
# Epoch 5/20
# ----------
# train Loss: 3.0698 Acc: 0.1483
# validation Loss: 3.0602 Acc: 0.1364
# Epoch 6/20
# ----------
# train Loss: 3.0643 Acc: 0.1700
# validation Loss: 3.0537 Acc: 0.1485
# Epoch 7/20
# ----------
# train Loss: 3.0582 Acc: 0.2054
# validation Loss: 3.0438 Acc: 0.2000
# Epoch 8/20
# ----------
# train Loss: 3.0515 Acc: 0.2137
# validation Loss: 3.0357 Acc: 0.2182
# Epoch 9/20
# ----------
# train Loss: 3.0434 Acc: 0.2466
# validation Loss: 3.0258 Acc: 0.2697
# Epoch 10/20
# ----------
# train Loss: 3.0352 Acc: 0.2730
# validation Loss: 3.0141 Acc: 0.3394
# Epoch 11/20
# ----------
# train Loss: 3.0242 Acc: 0.3090
# validation Loss: 2.9975 Acc: 0.3606
# Epoch 12/20
# ----------
# train Loss: 3.0123 Acc: 0.3282
# validation Loss: 2.9788 Acc: 0.4212
# Epoch 13/20
# ----------
# train Loss: 2.9976 Acc: 0.3340
# validation Loss: 2.9583 Acc: 0.4576
# Epoch 14/20
# ----------
# train Loss: 2.9806 Acc: 0.3444
# validation Loss: 2.9319 Acc: 0.4667
# Epoch 15/20
# ----------
# train Loss: 2.9582 Acc: 0.3568
# validation Loss: 2.8989 Acc: 0.4909
# Epoch 16/20
# ----------
# train Loss: 2.9351 Acc: 0.3502
# validation Loss: 2.8501 Acc: 0.4727
# Epoch 17/20
# ----------
# train Loss: 2.9032 Acc: 0.3609
# validation Loss: 2.8090 Acc: 0.4061
# Epoch 18/20
# ----------
# train Loss: 2.8614 Acc: 0.3776
# validation Loss: 2.7615 Acc: 0.4455
# Epoch 19/20
# ----------
# train Loss: 2.8196 Acc: 0.3749
# validation Loss: 2.7131 Acc: 0.4758
# Epoch 20/20
# ----------
# train Loss: 2.7666 Acc: 0.3908
# validation Loss: 2.6556 Acc: 0.4667
# Training complete
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 175
#     172     torch.save(results, 'shufflenet_training_results.pth')
#     174 if __name__ == '__main__':
# --> 175     train_model()
#
# Cell In[2], line 155, in train_model()
#     153 epochs = range(1, num_epochs + 1)
#     154 plt.figure(figsize=(12, 12))
# --> 155 plt.plot(epochs, train_accuracies, label='Train Accuracy', marker='o')
#     156 plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='x')
#     157 plt.xlabel('Epochs')
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3708, in plot(scalex, scaley, data, *args, **kwargs)
#    3700 @_copy_docstring_and_deprecators(Axes.plot)
#    3701 def plot(
#    3702     *args: float | ArrayLike | str,
#    (...)
#    3706     **kwargs,
#    3707 ) -> list[Line2D]:
# -> 3708     return gca().plot(
#    3709         *args,
#    3710         scalex=scalex,
#    3711         scaley=scaley,
#    3712         **({"data": data} if data is not None else {}),
#    3713         **kwargs,
#    3714     )
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:476, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     474 if len(xy) == 2:
#     475     x = _check_1d(xy[0])
# --> 476     y = _check_1d(xy[1])
#     477 else:
#     478     x, y = index_of(xy[-1])
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1411, in _check_1d(x)
#    1405 # plot requires `shape` and `ndim`.  If passed an
#    1406 # object that doesn't provide them, then force to numpy array.
#    1407 # Note this will strip unit information.
#    1408 if (not hasattr(x, 'shape') or
#    1409         not hasattr(x, 'ndim') or
#    1410         len(x.shape) < 1):
# -> 1411     return np.atleast_1d(x)
#    1412 else:
#    1413     return x
#
# File <__array_function__ internals>:200, in atleast_1d(*args, **kwargs)
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File c:\Users\Matthew\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:1087, in Tensor.__array__(self, dtype)
#    1085     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1086 if dtype is None:
# -> 1087     return self.numpy()
#    1088 else:
#    1089     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
